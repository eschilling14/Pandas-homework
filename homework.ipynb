# %%
import pandas as pd
purchase_file = "Resources/purchase_data.csv"
purchase_data = pd.read_csv(purchase_file)
purchase_data
# Out:
#      Purchase ID               SN  Age                 Gender  Item ID  \
# 0              0          Lisim78   20                   Male      108
# 1              1      Lisovynya38   40                   Male      143
# 2              2       Ithergue48   24                   Male       92
# 3              3    Chamassasya86   24                   Male      100
# 4              4        Iskosia90   23                   Male      131
# 5              5          Yalae81   22                   Male       81
# 6              6        Itheria73   36                   Male      169
# 7              7      Iskjaskst81   20                   Male      162
# 8              8        Undjask33   22                   Male       21
# 9              9      Chanosian48   35  Other / Non-Disclosed      136
# 10            10        Inguron55   23                   Male       95
# 11            11     Haisrisuir60   23                   Male      162
# ...

# %%
purchase_data.describe()
# Out:
#        Purchase ID         Age     Item ID       Price
# count   780.000000  780.000000  780.000000  780.000000
# mean    389.500000   22.714103   92.114103    3.050987
# std     225.310896    6.659444   52.775943    1.169549
# min       0.000000    7.000000    0.000000    1.000000
# 25%     194.750000   20.000000   48.000000    1.980000
# 50%     389.500000   22.000000   93.000000    3.150000
# 75%     584.250000   25.000000  139.000000    4.080000
# max     779.000000   45.000000  183.000000    4.990000

# %%
average=purchase_data["Price"].mean()
average
# Out:
# 3.050987179487176

# %%
count=purchase_data["Gender"].value_counts()
count
# Out:
# Male                     652
# Female                   113
# Other / Non-Disclosed     15
# Name: Gender, dtype: int64

# %%
total=purchase_data["Price"].sum()
total
# Out:
# 2379.77

# %%
purchase_data.columns
# Out:
# Index(['Purchase ID', 'SN', 'Age', 'Gender', 'Item ID', 'Item Name', 'Price'], dtype='object')

# %%
total_purchases=count.sum()
total_purchases
# Out:
# 780

# %%
total_players = len(purchase_data["SN"].value_counts())

players_df = pd.DataFrame({"Total Players": total_players}, index = [0])

players_df
# Out:
#    Total Players
# 0            576

# %%
unique_items = len(purchase_data["Item ID"].value_counts())
avg_pricetotal = purchase_data["Price"].mean()
total_purch = len(purchase_data["Price"])
total_rev = purchase_data["Price"].sum()
purch_analysis_df = pd.DataFrame({"Unique Items": unique_items, 
                                  "Average Price": avg_pricetotal, 
                                  "Number of Purchases": total_purch, 
                                  "Total Revenue": total_rev}, index = [0])
purch_analysis_df["Average Price"] = purch_analysis_df["Average Price"].map("${:.2f}".format)
purch_analysis_df["Total Revenue"] = purch_analysis_df["Total Revenue"].map("${:.2f}".format)

purch_analysis_df
# Out:
#    Unique Items Average Price  Number of Purchases Total Revenue
# 0           183         $3.05                  780      $2379.77

# %%
total
# Out:
# 2379.77

# %%
count
# Out:
# Male                     652
# Female                   113
# Other / Non-Disclosed     15
# Name: Gender, dtype: int64

# %%
purch_count = group_gender["Age"].count()
avg_purch = group_gender["Price"].mean()
total_purch = group_gender["Price"].sum()
avg_purch_by_person = (total_purch/unique_sn)

purch_by_g_df = pd.DataFrame({"Purchase Count": purch_count, 
                             "Average Purchase Price": avg_purch, 
                             "Total Purchase Value": total_purch, 
                            "Average Purchase by Person": avg_purch_by_person})

purch_by_g_df["Average Purchase Price"] = purch_by_g_df["Average Purchase Price"].map("${:.2f}".format)
purch_by_g_df["Total Purchase Value"] = purch_by_g_df["Total Purchase Value"].map("${:.2f}".format)
purch_by_g_df["Average Purchase by Person"] = purch_by_g_df["Average Purchase by Person"].map("${:.2f}".format)

purch_by_g_df
# Out:
#                        Purchase Count Average Purchase Price  \
# Gender
# Female                            113                  $3.20
# Male                              652                  $3.02
# Other / Non-Disclosed              15                  $3.35
#
#                       Total Purchase Value Average Purchase by Person
# Gender
# Female                             $361.94                      $4.47
# Male                              $1967.64                      $4.07
# Other / Non-Disclosed               $50.19                      $4.56

# %%
bins = [0, 9.5, 14.5, 19.5, 24.5, 29.5, 34.5, 39.5, 100]

bin_labels = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]

purchase_data["Ages"] = pd.cut(purchase_data["Age"], bins, labels = bin_labels)

grouped_age = purchase_data.groupby("Ages")
unique_sn = grouped_age["SN"].nunique()

age_demo = pd.DataFrame({"Total Counts": grouped_age["SN"].nunique(),
                           "Percentage of Players": unique_sn/total_players*100})
age_demo["Percentage of Players"] = age_demo["Percentage of Players"].map("{:.2f}".format)

age_demo
# Out:
#        Total Counts Percentage of Players
# Ages
# <10              17                  2.95
# 10-14            22                  3.82
# 15-19           107                 18.58
# 20-24           258                 44.79
# 25-29            77                 13.37
# 30-34            52                  9.03
# 35-39            31                  5.38
# 40+              12                  2.08

# %%
purch_count = grouped_age["Age"].count()
avg_purchase = grouped_age["Price"].mean()
total_purchase_value = grouped_age["Price"].sum()
avg_purch_by_person = (total_purch/unique_sn)


purchasing_by_age_df = pd.DataFrame({"Purchase count": purch_count,
                                       "Average purchase price": avg_purchase,
                                       "Total purchase value": total_purchase_value,
                                        "Avg Purchase by Person": total_purchase_value/unique_sn})

purchasing_by_age_df["Average purchase price"] = purchasing_by_age_df["Average purchase price"].map("${:.2f}".format)
purchasing_by_age_df["Total purchase value"] = purchasing_by_age_df["Total purchase value"].map("${:.2f}".format)
purchasing_by_age_df["Avg Purchase by person"] = purchasing_by_age_df["Avg Purchase by Person"].map("${:.2f}".format)


purchasing_by_age_df
# Out:
#        Purchase count Average purchase price Total purchase value  \
# Ages
# <10                23                  $3.35               $77.13
# 10-14              28                  $2.96               $82.78
# 15-19             136                  $3.04              $412.89
# 20-24             365                  $3.05             $1114.06
# 25-29             101                  $2.90              $293.00
# 30-34              73                  $2.93              $214.00
# 35-39              41                  $3.60              $147.67
# 40+                13                  $2.94               $38.24
#
#        Avg Purchase by Person Avg Purchase by person
# Ages
# <10                  4.537059                  $4.54
# 10-14                3.762727                  $3.76
# 15-19                3.858785                  $3.86
# 20-24                4.318062                  $4.32
# 25-29                3.805195                  $3.81
# ...

# %%
top_spenders = purchase_data.groupby("SN")
p_count = top_spenders["Age"].count()
avg_purch = top_spenders["Price"].mean()
total_purch = top_spenders["Price"].sum()
total_purchase_df = pd.DataFrame({"Purchase count": p_count,
                                       "Average purchase price": avg_purch,
                                       "Total purchase value": total_purch})
top_purchasers_df = pd.DataFrame({"Purchase count": p_count,
                                       "Average purchase price": avg_purch,
                                       "Total purchase value": total_purch})


top_purchasers_df = top_purchasers_df.sort_values("Total purchase value", ascending = False)


top_purchasers_df["Average purchase price"] = top_purchasers_df["Average purchase price"].map("${:.2f}".format)
top_purchasers_df["Total purchase value"] = top_purchasers_df["Total purchase value"].map("${:.2f}".format)


top_purchasers_df.iloc[0:5,:]
# Out:
#              Purchase count Average purchase price Total purchase value
# SN
# Lisosia93                 5                  $3.79               $18.96
# Idastidru52               4                  $3.86               $15.45
# Chamjask73                3                  $4.61               $13.83
# Iral74                    4                  $3.40               $13.62
# Iskadarya95               3                  $4.37               $13.10

# %%
group_items = purchase_data.groupby(["Item ID", "Item Name"])

purchase_count = group_items["Age"].count()
total_purchase_value = group_items["Price"].sum()
item_price = group_items["Price"].max() 

top_items_df = pd.DataFrame({"Purchase count": purchase_count,
                                       "Item price": item_price,
                                       "Total purchase value": total_purchase_value})


top_items_df = top_items_df.sort_values("Purchase count", ascending = False)


top_items_df["Total purchase value"] = top_items_df["Total purchase value"].map("${:.2f}".format)
top_items_df["Item price"] = top_items_df["Item price"].map("${:.2f}".format)

top_items_df.iloc[0:5,:]
# Out:
#                                                       Purchase count  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 145     Fiery Glass Crusader                                       9
# 108     Extraction, Quickblade Of Trembling Hands                  9
# 82      Nirvana                                                    9
# 19      Pursuit, Cudgel of Necromancy                              8
#
#                                                      Item price  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 145     Fiery Glass Crusader                              $4.58
# 108     Extraction, Quickblade Of Trembling Hands         $3.53
# 82      Nirvana                                           $4.90
# 19      Pursuit, Cudgel of Necromancy                     $1.02
#
#                                                      Total purchase value
# Item ID Item Name
# ...

# %%
prof_items_df = pd.DataFrame({"Purchase count": purchase_count,
                                       "Item price": item_price,
                                       "Total purchase value": total_purchase_value})
prof_items_df = prof_items_df.sort_values("Total purchase value", ascending = False)


prof_items_df["Total purchase value"] = prof_items_df["Total purchase value"].map("${:.2f}".format)
prof_items_df["Item price"] = prof_items_df["Item price"].map("${:.2f}".format)


prof_items_df.iloc[0:5,:]
# Out:
#                                                       Purchase count  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 82      Nirvana                                                    9
# 145     Fiery Glass Crusader                                       9
# 92      Final Critic                                               8
# 103     Singed Scalpel                                             8
#
#                                                      Item price  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 82      Nirvana                                           $4.90
# 145     Fiery Glass Crusader                              $4.58
# 92      Final Critic                                      $4.88
# 103     Singed Scalpel                                    $4.35
#
#                                                      Total purchase value
# Item ID Item Name
# ...
